# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras_visualizer import visualizer
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
model = Sequential()
model.add(Dense(20 , input_dim=5, activation='relu'))
model.add(Dense(1))

model.compile(
    loss="mean_squared_error", 
    optimizer='adam',
    metrics=['mean_squared_error']
)

# visualizer(model=model, file_name="GPT", file_format='png')
# Out:
# C:\Users\ariya\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
DF = pd.read_csv('dataset/co2.csv')

# %%
x = DF.drop('out1', axis=1)
y = DF['out1']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
h = model.fit(X_train,y_train, epochs=200)
# Out:
# Epoch 1/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 167.1667 - mean_squared_error: 167.1667
# Epoch 2/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 162.8373 - mean_squared_error: 162.8373
# Epoch 3/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 189.5506 - mean_squared_error: 189.5506
# Epoch 4/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 162.4708 - mean_squared_error: 162.4708
# Epoch 5/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 181.1144 - mean_squared_error: 181.1144
# Epoch 6/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 171.4064 - mean_squared_error: 171.4064
# Epoch 7/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 158.9731 - mean_squared_error: 158.9731
# Epoch 8/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 175.6113 - mean_squared_error: 175.6113
# Epoch 9/200
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 175.6094 - mean_squared_error: 175.6094
# Epoch 10/200
# ...

# %%
Y_pred = model.predict(X_test)
# Y_pred[0].astype(int)
print(Y_pred[4][0].astype(int))
y_test
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 210
# 6182    315
# 4962    241
# 210     347
# 4374    210
# 7301    210
#        ...
# 4124    210
# 6347    219
# 2739    269
# 1196    253
# 204     209
# Name: out1, Length: 1477, dtype: int64

# %%
test = np.array([[
    2,4,9.9,6.7,8.5
]])

out = model.predict(test)[0].astype(int)
print(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [198]
